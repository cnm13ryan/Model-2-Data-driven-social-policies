# %%
# Data Handling
import pandas as pd
import numpy as np
import math

# Regression Analysis
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Surpress IPython warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Research Question
#
# ### What is the change in mental health over the two year period between 2018 and 2020?
#
# <!-- ### Implicit Hypothesis 1 (expectation): There is a increase in mental health from 2018 to 2019 -->
#
# #### $H_{10}$: There is no significant change in mental health from 2018 to 2019
# #### $H_{1A}$:: There is a significant change in mental health from 2018 to 2019
#
# <!-- ### Implicit hypothesis 2 (expectation): There is an decrease in mental health from 2019 to 2020 -->
#
# #### $H_{20}$:: There is no significant change in mental health from 2019 to 2020
# #### $H_{2A}$: There is a significant change in mental health from 2019 to 2020

# %% [markdown]
# Since we only concern on the self-rated mental health,
# We can remove all the other entries.
#
# After some spreadcheet cleaning, we now get the following data sheet

# %%
data_directory = 'Data'

# %% [markdown]
# ## Self-rated mental health dataset

# %%
# Load listings data set
df1 = pd.read_csv(f"{data_directory}/mentalHealth.csv", sep=',', quotechar='"')
df1
# Out:
#     Year Region       Category                     Topic  \
# 0   2018    ACT  Mental health  Self-rated mental health
# 1   2020    ACT  Mental health  Self-rated mental health
# 2   2018    ACT  Mental health  Self-rated mental health
# 3   2020    ACT  Mental health  Self-rated mental health
# 4   2018    ACT  Mental health  Self-rated mental health
# ..   ...    ...            ...                       ...
# 76  2019    ACT  Mental health  Self-rated mental health
# 77  2020    ACT  Mental health  Self-rated mental health
# 78  2018    ACT  Mental health  Self-rated mental health
# 79  2019    ACT  Mental health  Self-rated mental health
# 80  2020    ACT  Mental health  Self-rated mental health
#
#                  Indicator       Age     Sex  Result      Unit  95% CI (L)  \
# 0   1. Excellent/very good  05 to 17  Person    72.7  Per cent        65.3
# 1   1. Excellent/very good  05 to 17  Person    71.4  Per cent        67.7
# ...

# %% [markdown]
# ### Missing values
# Is there anything missing in the self-rated mental health dataframe

# %%
df1.isna().sum()
# Out:
# Year              0
# Region            0
# Category          0
# Topic             0
# Indicator         0
# Age               0
# Sex               0
# Result            0
# Unit              0
# 95% CI (L)        0
# 95% CI (U)        0
# SE                0
# RSE > 25%        77
# Notes            81
# Sex_indicator     0
# Year_Sex          0
# Sex_Year          0
# dtype: int64

# %% [markdown]
# ### How do these counts look in the bigger picture. We certainty can visualize the ratio:

# %%
# Change figure size for printing
sns.set(rc={'figure.figsize':(11.7,8.27)})

# Calculate percentage of missing values for each column
df_miss_perc = df1.isna().mean() * 100

# Drop columns without missing values
miss_perc = df_miss_perc[df_miss_perc > 0]

if len(miss_perc) == 0:
    raise Exception('no missing values!')

ax = sns.barplot(x=miss_perc.index, y=miss_perc.values)
foo = ax.set_title("Missing values per column in percentage for self-rated mental health")

# %% [markdown]
# #### There are 2 columns affected by missing values in our listing data set. Since we do not use `RSE > 25%` and `Notes` such that we do nothing.
#
# #### We can now delete the irrelevant columns such as `Sex_indicator`, `Year_Sex`, and `Sex_Year`.

# %%
df1 = df1.drop(columns=['Sex_indicator', 'Year_Sex', 'Sex_Year'])

# %% [markdown]
# ## Categorise the self-rated mental health data set
#
# #### The data set is categorised in the following format

# %%
df11 = df1.groupby(['Topic', 'Age', 'Year', 'Indicator', 'Sex']).mean().reset_index()

# %%
df1count= df1.groupby(['Topic', 'Year', 'Sex'])['Region'].count()
df1count
# Out:
# Topic                     Year  Sex
# Self-rated mental health  2018  Female     6
#                                 Male       6
#                                 Person    18
#                           2019  Female     3
#                                 Male       3
#                                 Person    15
#                           2020  Female     6
#                                 Male       6
#                                 Person    18
# Name: Region, dtype: int64

# %% [markdown]
# ### Since the Person column is the total estimate of all the sexes such that we can ignore the effects of sex for our analysis of self-rated mental health

# %%
df_Persons1 = df11.loc[df11['Sex'].isin(['Person'])].reset_index().drop(columns=['index', 'Sex', 'RSE > 25%','Notes'])
df_Persons1
# Out:
#                        Topic       Age  Year               Indicator  Result  \
# 0   Self-rated mental health  05 to 17  2018  1. Excellent/very good    72.7
# 1   Self-rated mental health  05 to 17  2018                 2. Good    21.1
# 2   Self-rated mental health  05 to 17  2018            3. Fair/poor     6.2
# 3   Self-rated mental health  05 to 17  2020  1. Excellent/very good    71.4
# 4   Self-rated mental health  05 to 17  2020                 2. Good    20.8
# 5   Self-rated mental health  05 to 17  2020            3. Fair/poor     7.7
# 6   Self-rated mental health  18 to 24  2018  1. Excellent/very good    39.2
# 7   Self-rated mental health  18 to 24  2018                 2. Good    32.0
# 8   Self-rated mental health  18 to 24  2018            3. Fair/poor    28.8
# 9   Self-rated mental health  18 to 24  2019  1. Excellent/very good    40.4
# 10  Self-rated mental health  18 to 24  2019                 2. Good    37.7
# ...

# %%
df_Persons1.count()[0]
# Out:
# 51

# %% [markdown]
# ### Let's now normalise the mental health results by putting weightings on each mental health categories
#
# #### 1. Excellent / very good : Score 1
# #### 2. Good : Score 0
# #### 2. Fair/ poor: Score -1

# %%
def quantifyScore(DataFrame, ColumnName='Indicator', lst=[1, 0, -1]):
    """
    Normalise the mental health categorised results by assigning scores according to the list
    [Category1_score, Category2_score, Category3_score]
    """
    
    def zerolistmaker(n):
        listofzeros = [0] * n
        return listofzeros
    
    def calScores(DataFrame, ColumnName, lst):
        """
        Calculate the scores of the respective sections:
        Result, 95% CI (L), 95% CI (U), SE
        """
        def factor(category):
            """Return a factor value based on the category"""
            factor = 0
            if (category == "1. Excellent/very good"):
                factor = lst[0]
            elif (category == "2. Good"):
                factor = lst[1]
            elif (category == "3. Fair/poor"):
                factor = lst[2]
            else:
                raise Exception(f"{category} is an invalid category")
            return factor
        
        
        n = DataFrame.count()[0]
        #print(n)
        empty = zerolistmaker(n)
        tmp = DataFrame.assign(LCI95Scores=empty)
        DataFrame = tmp.assign(ResultScores=empty)
        tmp = DataFrame.assign(UCI95Scores=empty)
        DataFrame = tmp.assign(SEScores=empty)
    
        for i in range(n):
            category = DataFrame[ColumnName][i]
            lower = DataFrame["95% CI (L)"][i]
            middle = DataFrame["Result"][i]
            upper = DataFrame["95% CI (U)"][i]
            SE = DataFrame["SE"][i]
            factval = factor(category)
        
            DataFrame["LCI95Scores"][i] = factval * lower
            DataFrame["ResultScores"][i] = factval * middle
            DataFrame["UCI95Scores"][i] = factval * upper
            DataFrame["SEScores"][i] = factval * SE
            
        return DataFrame
        
    def combine(tmp, lst):
        
        def assign(tmp, lst, idx, vallst):
            """
            Assign a value of val to the idx index of the tmp[lst(iter)] variable
            """
            n = len(lst)
            for i in range(n):
                tmp[lst[i]][idx] = vallst[i]
            return tmp
        
        n = tmp.count()[0]
        total = []
        m = len(lst)
        for i in lst:
            total.append(tmp[i][0])
        #print(total)
        
        cnt = 0
        for i in range(1, n):
            lower = tmp["LCI95Scores"][i]
            middle = tmp["ResultScores"][i]
            upper = tmp["UCI95Scores"][i]
            SE = tmp["SEScores"][i]   
        
            if (tmp["Year"][i] == tmp["Year"][i-1]):
                total[0] += lower
                total[1] += middle
                total[2] += upper
                total[3] += SE
                tmp = assign(tmp, lst, i, zerolistmaker(len(lst)))
                cnt += 1
                
            else: 
                tmp = assign(tmp, lst, i-1, [total[0], total[1], total[2], total[3]])
                tmp = assign(tmp, lst, i-cnt-1, zerolistmaker(len(lst)))
                cnt = 0
                
        return tmp
    
    def rearrange(tmp, lst):
        """
        Reorder the lst = [Category 1, Category 2]
        where Category 1 = 95% CI (L), Category 2 = 95% CI (U)
        """
        
        n = tmp.count()[0]
        l = lst[0]
        u = lst[1]
        for i in range(n):
            lower = tmp[l][i]
            upper = tmp[u][i]
            if (lower > upper):
                tmp[l][i] = upper
                tmp[u][i] = lower
        
        return tmp
    
    
    
    tmp = calScores(DataFrame, ColumnName, lst)
    DataFrame = combine(tmp,["LCI95Scores", "ResultScores", "UCI95Scores", "SEScores"])
    tmp = rearrange(DataFrame, ["LCI95Scores","UCI95Scores"])
    
    # Drop all the zeros and reset the indexing
    DataFrame = tmp.drop(tmp[(tmp == 0).any(axis=1)].index)
    tmp = DataFrame.reset_index().drop(columns=["index"])
    
    return tmp

# %%
df_score = quantifyScore(df_Persons1).drop(columns=["Indicator", "Result", "95% CI (L)", "95% CI (U)", "SE"])
df_score
# Out:
#                        Topic       Age  Year  LCI95Scores  ResultScores  \
# 0   Self-rated mental health  05 to 17  2018         61.6          66.5
# 1   Self-rated mental health  05 to 17  2020         55.7          58.8
# 2   Self-rated mental health  18 to 24  2018         16.0          30.0
# 3   Self-rated mental health  18 to 24  2019        -17.9           8.1
# 4   Self-rated mental health  18 to 24  2020        -73.6         -31.5
# 5   Self-rated mental health       18+  2018        -93.3         -48.3
# 6   Self-rated mental health       18+  2019       -112.8         -65.3
# 7   Self-rated mental health       18+  2020       -135.7         -85.0
# 8   Self-rated mental health  25 to 44  2018       -157.3        -102.0
# 9   Self-rated mental health  25 to 44  2019       -180.3        -120.6
# 10  Self-rated mental health  25 to 44  2020       -205.8        -141.0
# 11  Self-rated mental health  45 to 64  2018       -225.4        -156.3
# ...

# %%
df_score1 = df_score.groupby(['Topic', 'Age', 'Year'])
#df1count= df1.groupby(['Topic', 'Year', 'Sex'])['Region'].count()

# %%
df_score1.head(30)
# Out:
#                        Topic       Age  Year  LCI95Scores  ResultScores  \
# 0   Self-rated mental health  05 to 17  2018         61.6          66.5
# 1   Self-rated mental health  05 to 17  2020         55.7          58.8
# 2   Self-rated mental health  18 to 24  2018         16.0          30.0
# 3   Self-rated mental health  18 to 24  2019        -17.9           8.1
# 4   Self-rated mental health  18 to 24  2020        -73.6         -31.5
# 5   Self-rated mental health       18+  2018        -93.3         -48.3
# 6   Self-rated mental health       18+  2019       -112.8         -65.3
# 7   Self-rated mental health       18+  2020       -135.7         -85.0
# 8   Self-rated mental health  25 to 44  2018       -157.3        -102.0
# 9   Self-rated mental health  25 to 44  2019       -180.3        -120.6
# 10  Self-rated mental health  25 to 44  2020       -205.8        -141.0
# 11  Self-rated mental health  45 to 64  2018       -225.4        -156.3
# ...

# %% [markdown]
# #### Split the dataframe according to the different age groups

# %%
dfScoreA = df_score[:2] # Age: 05 to 17
dfScoreB = df_score[2:5].reset_index().drop(columns=["index"]) # Age: 18 to 24
dfScoreC = df_score[5:8].reset_index().drop(columns=["index"]) # Age: 18+
dfScoreD = df_score[8:11].reset_index().drop(columns=["index"]) # Age: 25 to 44
dfScoreE = df_score[11:14].reset_index().drop(columns=["index"]) # Age: 45 to 64
dfScoreF = df_score[14:].reset_index().drop(columns=["index"]) # Age: 65+

# %% [markdown]
# ### We now have normalize the self-rated mental health results into scores such that we can now do a regression analysis for both independent variables `Age` and `Year`

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1)

ax1.plot(dfScoreA["Year"], dfScoreA["LCI95Scores"], "k--", label='Age: 05 to 17 $95 \% $CI (L)')
ax1.scatter(dfScoreA["Year"], dfScoreA["ResultScores"], c="black",label='Age: 05 to 17 Results')
ax1.plot(dfScoreA["Year"], dfScoreA["UCI95Scores"], "k-", label='Age: 05 to 17 $95 \% $CI (U)')

ax1.plot(dfScoreB["Year"], dfScoreB["LCI95Scores"], "g--", label='Age: 18 to 24 $95 \% $CI (L)')
ax1.scatter(dfScoreB["Year"], dfScoreB["ResultScores"], c="green",label='Age: 18 to 24 Results')
ax1.plot(dfScoreB["Year"], dfScoreB["UCI95Scores"], "g-", label='Age: 18 to 24 $95 \% $CI (U)')

ax2.plot(dfScoreC["Year"], dfScoreC["LCI95Scores"], "k--", label='Age: 18+ $95 \% $CI (L)')
ax2.scatter(dfScoreC["Year"], dfScoreC["ResultScores"], c="black",label='Age: 18+ Results')
ax2.plot(dfScoreC["Year"], dfScoreC["UCI95Scores"], "k-", label='Age: 18+ $95 \% $CI (U)')
            
ax2.plot(dfScoreD["Year"], dfScoreD["LCI95Scores"], "g--", label='Age: 25 to 44 $95 \% $CI (L)')
ax2.scatter(dfScoreD["Year"], dfScoreD["ResultScores"], c="green",label='Age: 25 to 44 Results')
ax2.plot(dfScoreD["Year"], dfScoreD["UCI95Scores"], "g-", label='Age: 25 to 44 $95 \% $CI (U)')

ax3.plot(dfScoreE["Year"], dfScoreE["LCI95Scores"], "k--", label='Age: 45 to 64 $95 \% $CI (L)')
ax3.scatter(dfScoreE["Year"], dfScoreE["ResultScores"], c="black",label='Age: 45 to 64 Results')
ax3.plot(dfScoreE["Year"], dfScoreE["UCI95Scores"], "k-", label='Age: 45 to 64 $95 \% $CI (U)')

ax3.plot(dfScoreF["Year"], dfScoreF["LCI95Scores"], "g--", label='Age: 65+ $95 \% $CI (L)')
ax3.scatter(dfScoreF["Year"], dfScoreF["ResultScores"], c="green",label='Age: 65+ to 17 Results')
ax3.plot(dfScoreF["Year"], dfScoreF["UCI95Scores"], "g-", label='Age: 65+ $95 \% $CI (U)')
    
    
    
ax1.set(ylabel='Self-rated Mental Health Scores')
ax2.set(ylabel='Self-rated Mental Health Scores')
ax3.set(xlabel='Year', ylabel='Self-rated Mental Health Scores')

ax1.legend(loc='center left',fontsize=12, bbox_to_anchor=(1, 0.5), fancybox=True)
ax2.legend(loc='center left',fontsize=12, bbox_to_anchor=(1, 0.5), fancybox=True)
ax3.legend(loc='center left',fontsize=12, bbox_to_anchor=(1, 0.5), fancybox=True)

ax1.grid(True)
ax2.grid(True)

ax1.set_title('Self-rated Mental Health Scores versus Age', fontsize=15)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
print('')

# %% [markdown]
# # Regression Analysis

# %% [markdown]
# ### Age: 18 to 24

# %%
x_train = np.array([2018, 2019, 2020]).reshape((-1, 1))
y_train = np.array([dfScoreB["ResultScores"][0], 
                    dfScoreB["ResultScores"][1],
                   dfScoreB["ResultScores"][2]])

x_test = np.array([2018, 2019, 2020]).reshape((-1, 1))
y_test = np.array(dfScoreB["ResultScores"])

lr = LinearRegression()
lr.fit(x_train, y_train)

# Predicting Y from linear regression model
y_pred = lr.predict(x_train)

# Plotting graph (Training)
plt.scatter(x_train, y_train, color="red", marker="X")
plt.plot(x_train, y_pred, color="blue")
plt.title("Training: Self-rated Mental Health Scores versus Year (Age: 18 to 24)")
plt.xlabel("Year")
plt.ylabel("Self-rated Mental Health Scores")
plt.show()

# Plotting graph (Testing)
plt.scatter(x_test, y_test, color="red", marker="X")
plt.plot(x_train, y_pred, color="blue")
plt.title("Testing: Self-rated Mental Health Scores versus Year (Age: 18 to 24)")
plt.xlabel("Year")
plt.ylabel("Self-rated Mental Health Scores")
plt.show()


# Assigning Coefficient (gradient) to b
b = lr.coef_
print("Coefficient : ", b)

# Assigning y-intercept to a
a = lr.intercept_
print("Intercept : ", a)

# Mean Squared Error (MSE)
from sklearn import metrics
print('Mean Squared Error (MSE)  :  ', metrics.mean_squared_error(y_train, y_pred))

import statsmodels.api as sm
# Ordinary Least-Squares (OLS) estimator is called 
# to get regression summary
x_stat = sm.add_constant(x_train)
regsummary = sm.OLS(y_train, x_stat).fit()
regsummary.summary()
# print("Adjusted R-Square : ", regsummary.rsquared_adj)
# print("R-Square : ", regsummary.rsquared)
# Out:
# Coefficient :  [-30.75]
# Intercept :  62086.44999999998
# Mean Squared Error (MSE)  :   17.405000000000005
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     36.22
# Date:                Sun, 09 Apr 2023   Prob (F-statistic):              0.105
# Time:                        19:57:05   Log-Likelihood:                -8.5420
# No. Observations:                   3   AIC:                             21.08
# Df Residuals:                       1   BIC:                             19.28
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ## Age: 25 to 44

# %%
x_train = np.array([2018, 2019, 2020]).reshape((-1, 1))
y_train = np.array([dfScoreD["ResultScores"][0], 
                    dfScoreD["ResultScores"][1],
                   dfScoreD["ResultScores"][2]])

x_test = np.array([2018, 2019, 2020]).reshape((-1, 1))
y_test = np.array(dfScoreD["ResultScores"])

lr = LinearRegression()
lr.fit(x_train, y_train)

# Predicting Y from linear regression model
y_pred = lr.predict(x_train)

# Plotting graph (Training)
plt.scatter(x_train, y_train, color="red", marker="X")
plt.plot(x_train, y_pred, color="blue")
plt.title("Training: Self-rated Mental Health Scores versus Year (Age: 25 to 44)")
plt.xlabel("Year")
plt.ylabel("Self-rated Mental Health Scores")
plt.show()

# Plotting graph (Testing)
plt.scatter(x_test, y_test, color="red", marker="X")
plt.plot(x_train, y_pred, color="blue")
plt.title("Testing: Self-rated Mental Health Scores versus Year (Age: 25 to 44)")
plt.xlabel("Year")
plt.ylabel("Self-rated Mental Health Scores")
plt.show()


# Assigning Coefficient (gradient) to b
b = lr.coef_
print("Coefficient : ", b)

# Assigning y-intercept to a
a = lr.intercept_
print("Intercept : ", a)

# Mean Squared Error (MSE)
from sklearn import metrics
print('Mean Squared Error (MSE)  :  ', metrics.mean_squared_error(y_train, y_pred))

import statsmodels.api as sm
# Ordinary Least-Squares (OLS) estimator is called 
# to get regression summary
x_stat = sm.add_constant(x_train)
regsummary = sm.OLS(y_train, x_stat).fit()
regsummary.summary()
# print("Adjusted R-Square : ", regsummary.rsquared_adj)
# print("R-Square : ", regsummary.rsquared)
# Out:
# Coefficient :  [-19.5]
# Intercept :  39249.3
# Mean Squared Error (MSE)  :   0.1799999999999994
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                     1408.
# Date:                Sun, 09 Apr 2023   Prob (F-statistic):             0.0170
# Time:                        19:57:05   Log-Likelihood:                -1.6846
# No. Observations:                   3   AIC:                             7.369
# Df Residuals:                       1   BIC:                             5.566
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ## Age: 45 to 64

# %%
x_train = np.array([2018, 2019, 2020]).reshape((-1, 1))
y_train = np.array([dfScoreE["ResultScores"][0], 
                    dfScoreE["ResultScores"][1],
                   dfScoreE["ResultScores"][2]])

x_test = np.array([2018, 2019, 2020]).reshape((-1, 1))
y_test = np.array(dfScoreE["ResultScores"])

lr = LinearRegression()
lr.fit(x_train, y_train)

# Predicting Y from linear regression model
y_pred = lr.predict(x_train)

# Plotting graph (Training)
plt.scatter(x_train, y_train, color="red", marker="X")
plt.plot(x_train, y_pred, color="blue")
plt.title("Training: Self-rated Mental Health Scores versus Year (Age: 45 to 64)")
plt.xlabel("Year")
plt.ylabel("Self-rated Mental Health Scores")
plt.show()

# Plotting graph (Testing)
plt.scatter(x_test, y_test, color="red", marker="X")
plt.plot(x_train, y_pred, color="blue")
plt.title("Testing: Self-rated Mental Health Scores versus Year (Age: 45 to 64)")
plt.xlabel("Year")
plt.ylabel("Self-rated Mental Health Scores")
plt.show()


# Assigning Coefficient (gradient) to b
b = lr.coef_
print("Coefficient : ", b)

# Assigning y-intercept to a
a = lr.intercept_
print("Intercept : ", a)

# Mean Squared Error (MSE)
from sklearn import metrics
print('Mean Squared Error (MSE)  :  ', metrics.mean_squared_error(y_train, y_pred))

import statsmodels.api as sm
# Ordinary Least-Squares (OLS) estimator is called 
# to get regression summary
x_stat = sm.add_constant(x_train)
regsummary = sm.OLS(y_train, x_stat).fit()
regsummary.summary()
# print("Adjusted R-Square : ", regsummary.rsquared_adj)
# print("R-Square : ", regsummary.rsquared)
# Out:
# Coefficient :  [-16.6]
# Intercept :  33342.83333333331
# Mean Squared Error (MSE)  :   0.22222222222222224
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     826.7
# Date:                Sun, 09 Apr 2023   Prob (F-statistic):             0.0221
# Time:                        19:57:06   Log-Likelihood:                -2.0007
# No. Observations:                   3   AIC:                             8.001
# Df Residuals:                       1   BIC:                             6.199
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ## Age: 65+

# %%
x_train = np.array([2018, 2019, 2020]).reshape((-1, 1))
y_train = np.array([dfScoreF["ResultScores"][0], 
                    dfScoreF["ResultScores"][1],
                   dfScoreF["ResultScores"][2]])

x_test = np.array([2018, 2019, 2020]).reshape((-1, 1))
y_test = np.array(dfScoreF["ResultScores"])

lr = LinearRegression()
lr.fit(x_train, y_train)

# Predicting Y from linear regression model
y_pred = lr.predict(x_train)

# Plotting graph (Training)
plt.scatter(x_train, y_train, color="red", marker="X")
plt.plot(x_train, y_pred, color="blue")
plt.title("Training: Self-rated Mental Health Scores versus Year (Age: 65+)")
plt.xlabel("Year")
plt.ylabel("Self-rated Mental Health Scores")
plt.show()

# Plotting graph (Testing)
plt.scatter(x_test, y_test, color="red", marker="X")
plt.plot(x_train, y_pred, color="blue")
plt.title("Testing: Self-rated Mental Health Scores versus Year (Age: 65+)")
plt.xlabel("Year")
plt.ylabel("Self-rated Mental Health Scores")
plt.show()


# Assigning Coefficient (gradient) to b
b = lr.coef_
print("Coefficient : ", b)

# Assigning y-intercept to a
a = lr.intercept_
print("Intercept : ", a)

# Mean Squared Error (MSE)
from sklearn import metrics
print('Mean Squared Error (MSE)  :  ', metrics.mean_squared_error(y_train, y_pred))

import statsmodels.api as sm
# Ordinary Least-Squares (OLS) estimator is called 
# to get regression summary
x_stat = sm.add_constant(x_train)
regsummary = sm.OLS(y_train, x_stat).fit()
regsummary.summary()
# print("Adjusted R-Square : ", regsummary.rsquared_adj)
# print("R-Square : ", regsummary.rsquared)
# Out:
# Coefficient :  [134.55]
# Intercept :  -271768.74999999994
# Mean Squared Error (MSE)  :   4772.645
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.433
# Method:                 Least Squares   F-statistic:                     2.529
# Date:                Sun, 09 Apr 2023   Prob (F-statistic):              0.357
# Time:                        19:57:06   Log-Likelihood:                -16.963
# No. Observations:                   3   AIC:                             37.93
# Df Residuals:                       1   BIC:                             36.12
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...
